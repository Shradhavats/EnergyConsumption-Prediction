# %% [markdown]
# <a href="https://colab.research.google.com/github/Shradhavats/EnergyConsumption-Prediction/blob/main/Energyconsumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !gdown https://drive.google.com/file/d/1bvaXJJqNObOCkX-i475BNxpidk024pyx/view
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1bvaXJJqNObOCkX-i475BNxpidk024pyx
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1bvaXJJqNObOCkX-i475BNxpidk024pyx/view
# To: /content/view
# 91.1kB [00:00, 7.68MB/s]

# %%
df = pd.read_csv('/content/household_power_consumption.txt',sep=";")

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554323 entries, 0 to 554322
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   554323 non-null  object
#  1   Time                   554323 non-null  object
#  2   Global_active_power    554323 non-null  object
#  3   Global_reactive_power  554323 non-null  object
#  4   Voltage                554322 non-null  object
#  5   Global_intensity       554322 non-null  object
#  6   Sub_metering_1         554322 non-null  object
#  7   Sub_metering_2         554322 non-null  object
#  8   Sub_metering_3         550387 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 38.1+ MB

# %%
df.shape
# Out:
# (554323, 9)

# %%
df.tail()
# Out:
#             Date      Time Global_active_power Global_reactive_power  Voltage  \
# 554318  5/1/2008  16:02:00               1.646                 0.188  238.450
# 554319  5/1/2008  16:03:00               1.644                 0.190  238.510
# 554320  5/1/2008  16:04:00               1.646                 0.192  238.760
# 554321  5/1/2008  16:05:00               1.642                 0.190  238.540
# 554322  5/1/2008  16:06:00               1.648                    0.      NaN
#
#        Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 554318            7.000          0.000          0.000            17.0
# 554319            7.000          0.000          0.000            18.0
# 554320            7.000          0.000          0.000            17.0
# 554321            7.000          0.000          0.000            18.0
# 554322              NaN            NaN            NaN             NaN

# %%
df.describe(include = object)
# Out:
#              Date      Time Global_active_power Global_reactive_power Voltage  \
# count      554323    554323              554323                554323  554322
# unique        386      1440                3871                   440    2583
# top     27/6/2007  17:24:00               0.218                 0.000       ?
# freq         1440       385                4953                145070    3935
#
#        Global_intensity Sub_metering_1 Sub_metering_2
# count            554322         554322         554322
# unique              209             80             80
# top               1.000          0.000          0.000
# freq              55474         504110         388253

# %%
df.shape
# Out:
# (554323, 9)

# %%
df.isnull().any()
# Out:
# Date                     False
# Time                     False
# Global_active_power      False
# Global_reactive_power    False
# Voltage                   True
# Global_intensity          True
# Sub_metering_1            True
# Sub_metering_2            True
# Sub_metering_3            True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date                        0
# Time                        0
# Global_active_power         0
# Global_reactive_power       0
# Voltage                     1
# Global_intensity            1
# Sub_metering_1              1
# Sub_metering_2              1
# Sub_metering_3           3936
# dtype: int64

# %%
df.describe()
# Out:
#        Sub_metering_3
# count   550387.000000
# mean         5.874959
# std          8.218729
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         17.000000
# max         20.000000
