# %% [markdown]
# <a href="https://colab.research.google.com/github/Shradhavats/EnergyConsumption-Prediction/blob/main/energyconsumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Necessary Libraries
import pandas as pd
import numpy as np

# %%
# !gdown https://drive.google.com/file/d/1bvaXJJqNObOCkX-i475BNxpidk024pyx/view
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1bvaXJJqNObOCkX-i475BNxpidk024pyx
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1bvaXJJqNObOCkX-i475BNxpidk024pyx/view
# To: /content/view
# 91.3kB [00:00, 50.8MB/s]

# %%
df = pd.read_csv('/content/household_power_consumption.txt',sep=";")
# Out:
# <ipython-input-4-68e29b680bbb>:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/household_power_consumption.txt',sep=";")

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %% [markdown]
# **DATA** **EXPLORATION**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733851 entries, 0 to 733850
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   733851 non-null  object
#  1   Time                   733851 non-null  object
#  2   Global_active_power    733851 non-null  object
#  3   Global_reactive_power  733850 non-null  object
#  4   Voltage                733850 non-null  object
#  5   Global_intensity       733850 non-null  object
#  6   Sub_metering_1         733850 non-null  object
#  7   Sub_metering_2         733850 non-null  object
#  8   Sub_metering_3         729910 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 50.4+ MB

# %%
df.shape
# Out:
# (733851, 9)

# %%
df.tail()
# Out:
#             Date      Time Global_active_power Global_reactive_power Voltage  \
# 733846  9/5/2008  08:10:00               0.484                   0.2  238.73
# 733847  9/5/2008  08:11:00               0.478                   0.2  238.95
# 733848  9/5/2008  08:12:00                0.78                 0.202  238.19
# 733849  9/5/2008  08:13:00               0.922                 0.238  238.77
# 733850  9/5/2008  08:14:00                0.88                   NaN     NaN
#
#        Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 733846              2.2            0.0            0.0             1.0
# 733847              2.2            0.0            0.0             0.0
# 733848              3.6            0.0            0.0             1.0
# 733849              4.0            0.0            0.0             1.0
# 733850              NaN            NaN            NaN             NaN

# %%
df.describe(include = object)
# Out:
#              Date      Time Global_active_power Global_reactive_power Voltage  \
# count      733851    733851              733851                733850  733850
# unique        511      1440                5603                   772    3725
# top     28/8/2007  17:24:00               0.218                 0.000       ?
# freq         1440       510                5785                193569    3940
#
#        Global_intensity Sub_metering_1 Sub_metering_2
# count            733850         733850         733850
# unique              346            119            122
# top               1.000          0.000          0.000
# freq              68410         656767         510162

# %%
df.shape
# Out:
# (733851, 9)

# %% [markdown]
# **Finding Null Values **

# %%
df.isnull().any()
# Out:
# Date                     False
# Time                     False
# Global_active_power      False
# Global_reactive_power     True
# Voltage                   True
# Global_intensity          True
# Sub_metering_1            True
# Sub_metering_2            True
# Sub_metering_3            True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date                        0
# Time                        0
# Global_active_power         0
# Global_reactive_power       1
# Voltage                     1
# Global_intensity            1
# Sub_metering_1              1
# Sub_metering_2              1
# Sub_metering_3           3941
# dtype: int64

# %%
df.describe()
# Out:
#        Sub_metering_3
# count   729910.000000
# mean         6.021981
# std          8.276439
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         17.000000
# max         31.000000

# %% [markdown]
# Finding Percentage of null values

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Date                     0.000000
# Time                     0.000000
# Global_active_power      0.000000
# Global_reactive_power    0.000136
# Voltage                  0.000136
# Global_intensity         0.000136
# Sub_metering_1           0.000136
# Sub_metering_2           0.000136
# Sub_metering_3           0.537030
# dtype: float64

# %% [markdown]
# Finding Unique values

# %%
df.nunique()
# Out:
# Date                      511
# Time                     1440
# Global_active_power      5603
# Global_reactive_power     772
# Voltage                  3725
# Global_intensity          346
# Sub_metering_1            119
# Sub_metering_2            122
# Sub_metering_3             32
# dtype: int64
